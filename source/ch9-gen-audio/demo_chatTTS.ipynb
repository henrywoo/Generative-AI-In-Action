# %%
import ChatTTS
import torch
import torchaudio
from IPython.display import Audio

chat = ChatTTS.Chat()
chat.load_models() # Set to True for better performance


texts = ["PUT YOUR TEXT HERE",]

wavs = chat.infer(texts, )

torchaudio.save("output1.wav", torch.from_numpy(wavs[0]), 24000)
# Out:
# INFO:ChatTTS.core:use cuda:0
# WARNING:ChatTTS.core:vocos not initialized.
# WARNING:ChatTTS.core:gpt not initialized.
# WARNING:ChatTTS.core:tokenizer not initialized.
# WARNING:ChatTTS.core:dvae not initialized.
# WARNING:ChatTTS.core:vocos not initialized.
# WARNING:ChatTTS.core:gpt not initialized.
# WARNING:ChatTTS.core:tokenizer not initialized.
# WARNING:ChatTTS.core:dvae not initialized.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 12
#       7 chat.load_models() # Set to True for better performance
#      10 texts = ["PUT YOUR TEXT HERE",]
# ---> 12 wavs = chat.infer(texts, )
#      14 torchaudio.save("output1.wav", torch.from_numpy(wavs[0]), 24000)
#
# File ~/miniconda3/envs/genaibook/lib/python3.10/site-packages/ChatTTS/core.py:95, in Chat.infer(self, text, skip_refine_text, params_refine_text, params_infer_code, use_decoder)
#      94 def infer(self, text, skip_refine_text=False, params_refine_text={}, params_infer_code={}, use_decoder=False):
# ---> 95     assert self.check_model(use_decoder=use_decoder)
#      96     if not skip_refine_text:
#      97         text_tokens = refine_text(self.pretrain_models, text, **params_refine_text)['ids']
#
# AssertionError:
